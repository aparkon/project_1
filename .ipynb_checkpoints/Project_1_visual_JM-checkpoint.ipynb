# %%
import matplotlib.pyplot as plt
import mplcyberpunk
from MCForecastTools import MCSimulation

# %%
"""Adding cyberpuck style to the code"""
plt.style.use("cyberpunk")
mplcyberpunk.add_glow_effects()

plt.show()

# %% [markdown]
# Calculating Cumulative Returns
# Calculating Mean Returns
# 1000 Simulations of Cumulative Portfolio Return Trajectories Over the Next 900 Trading Days
# Plot all coins
# plot top 5
# Distribution of Final Cumuluative Returns Across All 10 Simulations
# calculate volatility
# Plot daily returns
# plot daily mean returns
# variance
# plot covariace with SP500
# calmar ratio analysis value over sum of value
# max drawdown
# Calculating beta for volatility

# %%
coin_mcsim_equal.sort_values(by=['Cumulative Return'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6e4c165336ad> in <module>
# ----> 1 coin_mcsim_equal.sort_values(by=['Cumulative Return'])
#
# NameError: name 'coin_mcsim_equal' is not defined
